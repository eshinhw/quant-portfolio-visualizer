# %%
from pytickersymbols import PyTickerSymbols
# https://pypi.org/project/pytickersymbols/

# %%
pyticker = PyTickerSymbols()

# %%
countries = pyticker.get_all_countries()
indices = pyticker.get_all_indices()
industries = pyticker.get_all_industries()

# %% [markdown]
# Available Countries

# %%
countries
# Out:
# ['Isle of Man',
#  'Mexico',
#  'Bermuda',
#  'Italy',
#  'Russian Federation',
#  'South Africa',
#  'Ireland',
#  'Cyprus',
#  'United States',
#  'Luxembourg',
#  'Czechia',
#  'Switzerland',
#  'Austria',
#  'United Kingdom',
#  'Israel',
#  'Argentina',
#  'Canada',
#  'Finland',
#  'Australia',
#  'China',
#  'Belgium',
#  'Netherlands',
#  'Sweden',
#  'Germany',
#  'Spain',
#  'France']

# %% [markdown]
# Available Indices

# %%
indices
# Out:
# ['OMX Stockholm 30',
#  'SDAX',
#  'DOW JONES',
#  'OMX Helsinki 25',
#  'CAC 40',
#  'IBEX 35',
#  'FTSE 100',
#  'TECDAX',
#  'NASDAQ 100',
#  'Switzerland 20',
#  'MOEX',
#  'S&P 500',
#  'CAC Mid 60',
#  'DAX',
#  'BEL 20',
#  'AEX',
#  'MDAX',
#  'S&P 100',
#  'EURO STOXX 50']

# %% [markdown]
# Available Industries

# %%
industries
# Out:
# ['Consumer Publishing',
#  'Financials',
#  'Industrials',
#  'Retailers',
#  'Diamonds',
#  'Household Products',
#  'Natural Gas Utilities',
#  'Consumer Cyclicals',
#  'Electric Utilities & IPPs',
#  'Retailing',
#  'Semiconductors',
#  'Oil Related Services and Equipment',
#  'Financial services',
#  'Casinos & Gaming',
#  'Passenger Transportation Services',
#  'Tobacco',
#  'Refining',
#  'consulting',
#  'Airport Services',
#  'Homebuilding / Household Goods',
#  'Metal',
#  'Healthcare Equipment & Supplies',
#  'Media',
#  'Enterprise Solutions',
#  'Passenger Transportation, Ground & Sea',
#  'HVAC',
#  'Optician',
#  'Business Support Services',
#  'Food Retail & Distribution',
#  'Steel',
#  'analysis',
#  'Internet Services',
#  'process industries',
#  'Gold mining',
#  'Integrated Oil & Gas',
#  'Tourism',
#  'Industrial Machinery & Equipment',
#  'Personal & Household Products & Services',
#  'Investment',
#  'Aluminium',
#  'Specialty Mining & Metals',
# ...

# %%
nasdaq = list(pyticker.get_stocks_by_index('NASDAQ 100'))

# %%
nasdaq
# Out:
# [{'id': 325,
#   'name': 'Apple Inc.',
#   'symbol': 'AAPL',
#   'country': 'United States',
#   'indices': ['DOW JONES', 'NASDAQ 100', 'S&P 100', 'S&P 500'],
#   'industries': ['Computers, Phones & Household Electronics',
#    'Technology',
#    'Technology Equipment',
#    'Phones & Handheld Devices'],
#   'symbols': [{'yahoo': 'APC.F', 'google': 'FRA:APC', 'currency': 'EUR'},
#    {'yahoo': 'AAPL', 'google': 'NASDAQ:AAPL', 'currency': 'USD'}],
#   'metadata': {'founded': 1976, 'employees': 137000},
#   'isins': ['US0378331005']},
#  {'id': 329,
#   'name': 'Cisco Systems Inc.',
#   'symbol': 'CSCO',
#   'country': 'United States',
#   'indices': ['DOW JONES', 'NASDAQ 100', 'S&P 100', 'S&P 500'],
#   'industries': ['Technology',
#    'Technology Equipment',
#    'Communications & Networking'],
#   'symbols': [{'yahoo': 'CIS.F', 'google': 'FRA:CIS', 'currency': 'EUR'},
#    {'yahoo': 'CSCO', 'google': 'NASDAQ:CSCO', 'currency': 'USD'}],
# ...
