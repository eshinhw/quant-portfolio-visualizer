# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_exec_path', 'get_handle_inheritable', 'get_in
# ...

# %%
os.mkdir('directory')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eshin\\Desktop\\GitHub'

# %%
os.chdir('C:\\Users\\eshin\\Desktop')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eshin\\Desktop'

# %%
os.listdir()
# Out:
# ['desktop.ini',
#  'GitHub',
#  'LOL',
#  'practice.aux',
#  'practice.log',
#  'practice.out',
#  'practice.pdf',
#  'practice.synctex.gz',
#  'practice.tex',
#  'UTSC']

# %%
os.chdir('C:\\Users\\eshin\\Desktop\\GitHub')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'directory',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.rmdir('directory')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.makedirs('directory/sub-dir')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'directory',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.chdir('directory')

# %%
os.listdir()
# Out:
# ['sub-dir']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eshin\\Desktop\\GitHub\\directory'

# %%
os.chdir('C:\\Users\\eshin\\Desktop\\GitHub')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eshin\\Desktop\\GitHub'

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'directory',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.removedirs('directory/sub-dir')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.mkdir('directory')

# %%
os.rename('directory', 'dir1')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  'data-structures-and-algorithms',
#  'dir1',
#  'Dual Momentum Strategy.ipynb',
#  'eclipse-java',
#  'investing-portfolio-risk-and-return-analyzer',
#  'learning-data-analytics-in-python',
#  'leetcode',
#  'OS.ipynb',
#  'quant-learning']

# %%
os.stat('dir1')
# Out:
# os.stat_result(st_mode=16895, st_ino=21673573206790119, st_dev=2818965785, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1599924863, st_mtime=1599924863, st_ctime=1599924863)

# %%
from datetime import datetime
# latest modified time
mod_time = os.stat('dir1').st_mtime
# prints out human readable time format
print(datetime.fromtimestamp(mod_time))
# Out:
# 2020-09-12 11:34:23.208828

# %%
# prints entire directory tree

for dirpath, dirname, filenames in os.walk('C:\\Users\\eshin\\Desktop\\GitHub'):
    print('Current Path: ', dirpath)
    print('Directories: ', dirname)
    print('Files: ', filenames)
    print()
# Out:
# Current Path:  C:\Users\eshin\Desktop\GitHub
# Directories:  ['.ipynb_checkpoints', 'data-structures-and-algorithms', 'dir1', 'eclipse-java', 'investing-portfolio-risk-and-return-analyzer', 'learning-data-analytics-in-python', 'leetcode', 'quant-learning']
# Files:  ['.bash_history', '.gitconfig', 'Dual Momentum Strategy.ipynb', 'OS.ipynb']
#
# Current Path:  C:\Users\eshin\Desktop\GitHub\.ipynb_checkpoints
# Directories:  []
# Files:  ['Dual Momentum Strategy-checkpoint.ipynb', 'groupby-checkpoint.ipynb', 'Joining Multiple DataFrames-checkpoint.ipynb', 'OS-checkpoint.ipynb']
#
# Current Path:  C:\Users\eshin\Desktop\GitHub\data-structures-and-algorithms
# Directories:  ['.git', 'algorithms', 'data-structures']
# Files:  ['README.md']
#
# Current Path:  C:\Users\eshin\Desktop\GitHub\data-structures-and-algorithms\.git
# Directories:  ['hooks', 'info', 'logs', 'objects', 'refs']
# ...

# %%
os.environ.get('HOME')
# Out:
# '/c/Users/eshin/Desktop/Github'

# %%
os.path.join(os.environ.get('HOME'),'test.txt')
# Out:
# '/c/Users/eshin/Desktop/Github\\test.txt'

# %%
os.path.basename(os.environ.get('HOME'))
# Out:
# 'Github'

# %%
os.path.dirname(os.environ.get('HOME'))
# Out:
# '/c/Users/eshin/Desktop'

# %%
os.path.split(os.environ.get('HOME'))
# Out:
# ('/c/Users/eshin/Desktop', 'Github')

# %%
os.path.exists(os.environ.get('HOME'))
# Out:
# True

# %%
os.path.isdir(os.environ.get('HOME'))
# Out:
# True

# %%
os.path.isfile(os.environ.get('HOME'))
# Out:
# False

# %%
os.path.splitext(os.environ.get('HOME'))
# Out:
# ('/c/Users/eshin/Desktop/Github', '')
