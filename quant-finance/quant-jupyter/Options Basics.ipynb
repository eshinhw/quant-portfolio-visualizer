# %% [markdown]
# # Calculate Implied Volatility

# %%
import mibian # documentation: https://github.com/yassinemaaroufi/MibianLib

# %%
# syntax: BS([UnderlyingPrice, StrikePrice, InterestRate, Daystoexpiration],callPrice=x)
c = mibian.BS([149.03, 148, 1, 2], callPrice=2.64)

# %%
c.impliedVolatility
# Out:
# 47.36328125

# %% [markdown]
# # Options Diagram

# %%
import opstrat as op

# %%
op.multi_plotter()
