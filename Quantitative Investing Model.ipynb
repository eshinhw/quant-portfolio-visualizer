# %%
import ratios
import pyticker
import momentum
import dividend
import pandas as pd

# %% [markdown]
# ## Equity Momentum

# %%
symbols = pyticker.get_symbols_by_index('DOW JONES')

data = {'Symbol': [], 'Momentum': []}

for symbol in symbols:
    data['Symbol'].append(symbol)
    try:
        data['Momentum'].append(momentum.calculate_equal_weight_momentum(symbol, [1,3,6,12,24,36]))
    except:
        data['Momentum'].append(0)

df = pd.DataFrame(data)
df.set_index('Symbol', inplace=True)
df
# Out:
#         Momentum
# Symbol
# MMM     0.143686
# AXP     0.378711
# AAPL    0.761379
# BA      0.189279
# CAT     0.582994
# CVX     0.221460
# CSCO    0.225970
# KO      0.151541
# GS      0.538932
# HD      0.440559
# IBM     0.105892
# INTC    0.230878
# JNJ     0.187651
# JPM     0.453991
# MCD     0.223690
# MRK     0.088527
# MSFT    0.574733
# NKE     0.380171
# PG      0.258632
# TRV     0.225709
# UNH     0.380471
# VZ      0.105878
# V       0.254526
# WMT     0.208479
# WBA     0.202742
# DIS     0.493839
# AMGN    0.238002
# HON     0.363587
# CRM     0.234139
# DOW     0.000000

# %%
df = df.sort_values(by='Momentum', ascending=False)
df
# Out:
#         Momentum
# Symbol
# AAPL    0.761379
# CAT     0.582994
# MSFT    0.574733
# GS      0.538932
# DIS     0.493839
# JPM     0.453991
# HD      0.440559
# UNH     0.380471
# NKE     0.380171
# AXP     0.378711
# HON     0.363587
# PG      0.258632
# V       0.254526
# AMGN    0.238002
# CRM     0.234139
# INTC    0.230878
# CSCO    0.225970
# TRV     0.225709
# MCD     0.223690
# CVX     0.221460
# WMT     0.208479
# WBA     0.202742
# BA      0.189279
# JNJ     0.187651
# KO      0.151541
# MMM     0.143686
# IBM     0.105892
# VZ      0.105878
# MRK     0.088527
# DOW     0.000000

# %%
top_ten = df.head(10)
top_ten
# Out:
#         Momentum
# Symbol
# AAPL    0.761379
# CAT     0.582994
# MSFT    0.574733
# GS      0.538932
# DIS     0.493839
# JPM     0.453991
# HD      0.440559
# UNH     0.380471
# NKE     0.380171
# AXP     0.378711

# %% [markdown]
# ## Financial Ratio Analysis

# %%
data = {'Symbol': [], 'Revenue_Growth': [], 'ROE': [], 'Dividend_Growth': [], 'Dividend_Yield': []}

for symbol in top_ten.index:
    print(symbol)
    fr = ratios.get_financial_ratios(symbol)
    data['Symbol'].append(symbol)
    data['Revenue_Growth'].append(fr.loc['revenueGrowth','Value'])
    data['ROE'].append(fr.loc['returnOnEquityTTM','Value'])
    data['Dividend_Growth'].append(dividend.calcualte_avg_dividend_growth(symbol,15))
    data['Dividend_Yield'].append(dividend.calculate_current_dividend_yield(symbol))

data
# Out:
# AAPL
# CAT
rowth': 0.0012422360248447205, 'dividendsperShareGrowth': -0.003993634823674397, 'operatingCashFlowGrowth': 0.6055045871559633, 'freeCashFlowGrowth': 0.6770662287903667, 'tenYRevenueGrowthPerShare': 0.3646639668420364, 'fiveYRevenueGrowthPerShare': 0.2895305771771647, 'threeYRevenueGrowthPerShare': 0.1227867020345509, 'tenYOperatingCFGrowthPerShare': 1.5146087800350185, 'fiveYOperatingCFGrowthPerShare': 0.4657784979146037, 'threeYOperatingCFGrowthPerShare': -0.24160726654216758, 'tenYNetIncomeGrowthPerShare': 1.005001696084968, 'fiveYNetIncomeGrowthPerShare': 0.9413233475428184, 'threeYNetIncomeGrowthPerShare': -2.2908772967615723, 'tenYShareholdersEquityGrowthPerShare': 1.0969470691113383, 'fiveYShareholdersEquityGrowthPerShare': 0.34933812609419734, 'threeYShareholdersEquityGrowthPerShare': 0.3549730162781514, 'tenYDividendperShareGrowthPerShare': 1.4701834731087386, 'fiveYDividendperShareGrowthPerShare': 0.44521902582543327, 'threeYDividendperShareGrowthPerShare': 0.1931943756430287, 'receivablesGrowth': 0.07539181460298597, 'inventoryGrowth': 0.0, 'assetGrowth': 0.021937530372371956, 'bookValueperShareGrowth': 0.04967984120010096, 'debtGrowth': -0.03613447185597832, 'rdexpenseGrowth': 0.0, 'sgaexpensesGrowth': 0.11221590909090909}
# {'Symbol': ['AAPL',
#   'CAT',
#   'MSFT',
#   'GS',
#   'DIS',
#   'JPM',
#   'HD',
#   'UNH',
#   'NKE',
#   'AXP'],
#  'Revenue_Growth': [0.722449,
#   0.137031,
#   0.159391,
#   -0.20081,
#   0.104848,
#   0.00264178,
#   -0.0380188,
#   0.00398369,
#   0.0612611,
#   0.040074],
#  'ROE': [0.905941,
#   0.206009,
#   0.421929,
#   0.0752211,
#   -0.0576169,
#   0.108274,
#   55.3376,
#   0.245151,
#   0.305811,
#   0.144269],
#  'Dividend_Growth': [0.23871160611983547,
#   inf,
#   0.7813463221625692,
#   0.1721383022405534,
#   0.16434704644424775,
#   0.12454129424975775,
#   0.24213960948664284,
#   1.0217430974329296,
#   0.39798370991042614,
#   0.09866640332823469],
#  'Dividend_Yield': [0.0059899118360938215,
#   0.017982628383851753,
#   0.008010732268660902,
#   0.014732747740181375,
#   0.009376362718646366,
#   0.023960066555740435,
#   0.018479734308702773,
#   0.012073505918380767,
#   0.007771920940088398,
#   0.011880094035792705]}

# %%
ratio_df = pd.DataFrame(data)
ratio_df.set_index('Symbol', inplace=True)
ratio_df = ratio_df[(ratio_df['Revenue_Growth'] > 0.05) & (ratio_df['ROE'] > 0.10)]
ratio_df
# Out:
#         Revenue_Growth       ROE  Dividend_Growth  Dividend_Yield
# Symbol
# AAPL          0.722449  0.905941         0.238712        0.005990
# CAT           0.137031  0.206009              inf        0.017983
# MSFT          0.159391  0.421929         0.781346        0.008011
# NKE           0.061261  0.305811         0.397984        0.007772
