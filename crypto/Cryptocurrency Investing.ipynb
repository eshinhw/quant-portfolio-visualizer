# %%
import os
import sys

currDir = os.getcwd()
parentDir = os.path.abspath(os.path.join(currDir, os.pardir))
grandParentDir = os.path.abspath(os.path.join(parentDir, os.pardir))

# print(currDir)
# print(parentDir)
# print(grandParentDir)

sys.path.append(parentDir) # append parent path
sys.path.append(grandParentDir) # append home repo dir

# %%
import fmp
import requests
import credentials

# %%
cryptos = fmp.crypto_list()
cryptos
# Out:
# ['XVGUSD',
#  'AAVEUSD',
#  'ECAUSD',
#  'TFUELUSD',
#  'NIXUSD',
#  'MHCUSD',
#  'IDNAUSD',
#  'CTXCUSD',
#  'VGXUSD',
#  'KAVAUSD',
#  'DEROUSD',
#  'FSNUSD',
#  'SLSUSD',
#  'SPHRUSD',
#  'POLISUSD',
#  'TUSDUSD',
#  'ARRRUSD',
#  'SOL1USD',
#  'PMEERUSD',
#  'ACTUSD',
#  'MANAUSD',
#  'WOZXUSD',
#  'SRKUSD',
#  'BTCUSD',
#  'XRPUSD',
#  'ETHUSD',
#  'BCHUSD',
#  'USDTUSD',
#  'SNMUSD',
#  'TUBEUSD',
#  'SBDUSD',
#  'BSVUSD',
#  'ERKUSD',
#  'CRWUSD',
#  'RBTCUSD',
#  'BHD-USD',
#  'DNTUSD',
#  'DIVIUSD',
#  'COTIUSD',
#  'OUROUSD',
#  'LBCUSD',
#  'NMRUSD',
#  'BDXUSD',
#  'SFTUSD',
#  'XDNUSD',
#  'RBYUSD',
#  'CHIUSD',
#  'VTHOUSD',
#  'BIPUSD',
#  'OBSRUSD',
#  'ECCUSD',
#  'VLXUSD',
#  'KRTUSD',
#  'MRXUSD',
#  'BANDUSD',
#  'GRNUSD',
#  'FRONTUSD',
#  'TWTUSD',
#  'XHVUSD',
#  'NYEUSD',
#  'MEDUSD',
#  'HTMLUSD',
#  'QASHUSD',
#  'ICXUSD',
#  'MASSUSD',
#  'LTCUSD',
#  'BNBUSD',
#  'LINKUSD',
#  'EOSUSD',
#  'XLMUSD',
#  'TRXUSD',
#  'ADAUSD',
#  'XMRUSD',
#  'DASHUSD',
#  'ETCUSD',
#  'NEOUSD',
#  'XEMUSD',
#  'BATUSD',
#  'ZECUSD',
#  'DOGEUSD',
#  'ZRXUSD',
#  'DCRUSD',
#  'QTUMUSD',
#  'GNOUSD',
#  'BTGUSD',
#  'OMGUSD',
#  'LSKUSD',
#  'MCOUSD',
#  'DGBUSD',
#  'SNTUSD',
#  'MONAUSD',
#  'BTSUSD',
#  'BTMUSD',
#  'BCNUSD',
#  'KMDUSD',
#  'MAIDUSD',
#  'SCUSD',
#  'ARDRUSD',
#  'STORJUSD',
#  'GNTUSD',
#  'FCTUSD',
#  'ETPUSD',
#  'STRATUSD',
#  'XUCUSD',
#  'PPTUSD',
#  'BTCDUSD',
#  'ZENUSD',
#  'MTLUSD',
#  'DGDUSD',
#  'ANTUSD',
#  'BNTUSD',
#  'PAYUSD',
#  'RLCUSD',
#  'ARKUSD',
#  'VERIUSD',
#  'ICNUSD',
#  'FAIRUSD',
#  'PIVXUSD',
#  'SYSUSD',
#  'STEEMUSD',
#  'NXTUSD',
#  'NXSUSD',
#  'GASUSD',
#  'GBYTEUSD',
#  'VTCUSD',
#  'SNGLSUSD',
#  'SALTUSD',
#  'AEUSD',
#  'QRLUSD',
#  'FRSTUSD',
#  'PARTUSD',
#  'SMARTUSD',
#  'NEBLUSD',
#  'KINUSD',
#  'NAVUSD',
#  'TAASUSD',
#  'BLOCKUSD',
#  'XCPUSD',
#  'MLNUSD',
#  'SUBUSD',
#  'WINGSUSD',
#  'GAMEUSD',
#  'IOCUSD',
#  'MGOUSD',
#  'NLC2USD',
#  'ATBUSD',
#  'ADXUSD',
#  'FILUSD',
#  'BALUSD',
#  'NANOUSD',
#  'ZNNUSD',
#  'MATICUSD',
#  'CETUSD',
#  'BTXUSD',
#  'NRGUSD',
#  'SXPUSD',
#  'NVTUSD',
#  'TERAUSD',
#  'CHZUSD',
#  'ABBCUSD',
#  'HPBUSD',
#  'DYNUSD',
#  'TTUSD',
#  'CELOUSD',
#  'AEONUSD',
#  'ETNUSD',
#  'XSNUSD',
#  'FETUSD',
#  'CUTUSD',
#  'POAUSD',
#  'USDCUSD',
#  'NMCUSD',
#  'SAPPUSD',
#  'VITEUSD',
#  'BHPUSD',
#  'QRKUSD',
#  'WABIUSD',
#  'IOTXUSD',
#  'VINUSD',
#  'MANUSD',
#  'XLTUSD',
#  'BCDUSD',
#  'CELUSD',
#  'PACUSD',
#  'XNCUSD',
#  'INSTARUSD',
#  'ATRIUSD',
#  'HYCUSD',
#  'ERGUSD',
#  'MINTUSD',
#  'XBYUSD',
#  'AVAXUSD',
#  'GXCUSD',
#  'IOSTUSD',
#  'FTMUSD',
#  'REVUSD',
#  'XDCUSD',
#  'NUUSD',
#  'DIMEUSD',
#  'DACCUSD',
#  'ADKUSD',
#  'ROSEUSD',
#  'PHAUSD',
#  'XMCUSD',
#  'VBKUSD',
#  'ENJUSD',
#  'MKRUSD',
#  'WGRUSD',
#  'VEXUSD',
#  'PZMUSD',
#  'HNCUSD',
#  'UMAUSD',
#  'CTSIUSD',
#  'XMYUSD',
#  'METAUSD',
#  'TRUEUSD',
#  'XASUSD',
#  'OMIUSD',
#  'SOLVEUSD',
#  'SCPUSD',
#  'FTXUSD',
#  'BEAMUSD',
#  'RVNUSD',
#  'ANKRUSD',
#  'ZYNUSD',
#  'CRUUSD',
#  'QNTUSD',
#  'PAIUSD',
#  'PIUSD',
#  'DFIUSD',
#  'CKBUSD',
#  'OTOUSD',
#  'DMDUSD',
#  'HIVEUSD',
#  'WAXPUSD',
#  'FLASHUSD',
#  'ZELUSD',
#  'CUDOSUSD',
#  'HTDFUSD',
#  'THETAUSD',
#  'VIAUSD',
#  'DTEPUSD',
#  'DUNUSD',
#  'USNBTUSD',
#  'KDAUSD',
#  'SUSHIUSD',
#  'FIROUSD',
#  'CELRUSD',
#  'NYZOUSD',
#  'AVAUSD',
#  'YOYOWUSD',
#  'VSYSUSD',
#  'IRISUSD',
#  'SKYUSD',
#  'ELAUSD',
#  'ALIASUSD',
#  'PCXUSD',
#  'NKNUSD',
#  'SEROUSD',
#  'AXSUSD',
#  'MIRUSD',
#  'GHOSTUSD',
#  'WANUSD',
#  'TRTLUSD',
#  'NLGUSD',
#  'LCCUSD',
#  'VRAUSD',
#  'DMCHUSD',
#  'XSTUSD',
#  'SANDUSD',
#  'OXTUSD',
#  'CSCUSD',
#  'PHRUSD',
#  'VETUSD',
#  'RUNEUSD',
#  'STRAXUSD',
#  'NASUSD',
#  'PPCUSD',
#  'CLVUSD',
#  'INTUSD',
#  'GLEECUSD',
#  'COMPUSD',
#  'HNSUSD',
#  'BEPROUSD',
#  'SRMUSD',
#  'EMC2USD',
#  'XRCUSD',
#  'BONOUSD',
#  'ARUSD',
#  'BCAUSD',
#  'KSMUSD',
#  'AMBUSD',
#  'RAYUSD',
#  'TOMOUSD',
#  'GRINUSD',
#  'NULSUSD',
#  'XWCUSD',
#  'DDKUSD',
#  'ZILUSD',
#  'AIBUSD',
#  'SNXUSD',
#  'XTZUSD',
#  'AIONUSD',
#  'LRGUSD',
#  'FLOUSD',
#  'REPUSD',
#  'WAVESUSD',
#  'WTCUSD',
#  'LRCUSD',
#  'XZCUSD',
#  'FUNUSD',
#  'CVCUSD',
#  'KNCUSD',
#  'CCXXUSD',
#  'MIDASUSD',
#  'DCYUSD',
#  'JDCUSD',
#  'EWTUSD',
#  'FTCUSD',
#  'RINGXUSD',
#  'CROUSD',
#  'HBARUSD',
#  'RDDUSD',
#  'FIOUSD',
#  'GRCUSD',
#  'SHIBUSD',
#  'CCAUSD',
#  'LOKIUSD',
#  'ALGOUSD',
#  'CLAMUSD',
#  'GLMUSD',
#  'NIMUSD',
#  'ZANOUSD',
#  'MBCUSD',
#  'BPSUSD',
#  'MAROUSD',
#  'GOUSD',
#  'ONTUSD',
#  'OWCUSD',
#  'ILCUSD',
#  'CAKEUSD',
#  'COLXUSD',
#  'AXELUSD',
#  'GRSUSD',
#  'BSTUSD',
#  'YFIUSD',
#  'MIOTAUSD',
#  'BLKUSD',
#  'AYAUSD',
#  'DAGUSD',
#  'MWCUSD',
#  'EGLDUSD',
#  'APLUSD',
#  'CUREUSD',
#  'MCAPUSD',
#  'STMXUSD',
#  'BTC2USD',
#  'UNOUSD',
#  'HEXUSD',
#  'SKLUSD',
#  'RSRUSD',
#  'WICCUSD',
#  'UBQUSD',
#  'EDGUSD',
#  'DCNUSD',
#  'LKKUSD',
#  'VENUSD',
#  'BCCOINUSD',
#  'HSRUSD',
#  'BQXUSD',
#  'IOTUSD',
#  'XRBUSD',
#  'ATMUSD']

# %%
'ADAUSD' in cryptos
# Out:
# True

# %%
fmp.crypto_prices('ADAUSD')
# Out:
# {'symbol': 'ADA/USD', 'historical': [{'date': '2021-10-10', 'open': 2.2709, 'high': 2.2765, 'low': 2.1863, 'close': 2.1963, 'adjClose': 2.1963, 'volume': 1642965345.0, 'unadjustedVolume': 1642965345.0, 'change': -0.0746, 'changePercent': -3.285, 'vwap': 2.2197, 'label': 'October 10, 21', 'changeOverTime': -0.03285}, {'date': '2021-10-09', 'open': 2.2356, 'high': 2.2994, 'low': 2.2253, 'close': 2.27, 'adjClose': 2.27, 'volume': 1552861736.0, 'unadjustedVolume': 1552861736.0, 'change': 0.0344, 'changePercent': 1.539, 'vwap': 2.2649, 'label': 'October 09, 21', 'changeOverTime': 0.01539}, {'date': '2021-10-08', 'open': 2.2788, 'high': 2.3071, 'low': 2.229, 'close': 2.2328, 'adjClose': 2.2328, 'volume': 1681496168.0, 'unadjustedVolume': 1681496168.0, 'change': -0.046, 'changePercent': -2.019, 'vwap': 2.2563, 'label': 'October 08, 21', 'changeOverTime': -0.02019}, {'date': '2021-10-07', 'open': 2.2152, 'high': 2.3614, 'low': 2.1633, 'close': 2.2802, 'adjClose': 2.2802, 'volume': 3009642143.0, 'unadjustedVolume': 3009642143.0, 'change': 0.065, 'changePercent': 2.934, 'vwap': 2.2683, 'label': 'October 07, 21', 'changeOverTime': 0.02934}, {'date': '2021-10-06', 'open': 2.233087, 'high': 2.250027, 'low': 2.116876, 'close': 2.212155, 'adjClose': 2.212155, 'volume': 2719301133.0, 'unadjustedVolume': 2719301133.0, 'change': -0.02093, 'changePercent': -0.937, 'vwap': 2.19302, 'label': 'October 06, 21', 'changeOverTime': -0.00937}, {'date': '2021-10-05', 'open': 2.189178, 'high': 2.256643, 'low': 2.181561, 'close': 2.233124, 'adjClose': 2.233124, 'volume': 2090074822.0, 'unadjustedVolume': 2090074822.0, 'change': 0.04395, 'changePercent': 2.008, 'vwap': 2.22378, 'label': 'October 05, 21', 'changeOverTime': 0.02008}, {'date': '2021-10-04', 'open': 2.251848, 'high': 2.253159, 'low': 2.1558, 'close': 2.189235, 'adjClose': 2.189235, 'volume': 2249001043.0, 'unadjustedVolume': 2249001043.0, 'change': -0.06261, 'changePercent': -2.78, 'vwap': 2.1994, 'label': 'October 04, 21', 'changeOverTime': -0.0278}, {'date': '2021-10-03', 'open': 2.249317, 'high': 2.307575, 'low': 2.223882, 'close': 2.252873, 'adjClose': 2.252873, 'volume': 2331706759.0, 'unadjustedVolume': 2331706759.0, 'change': 0.00356, 'changePercent': 0.158, 'vwap': 2.26144, 'label': 'October 03, 21', 'changeOverTime': 0.00158}, {'date': '2021-10-02', 'open': 2.254531, 'high': 2.320416, 'low': 2.195434, 'close': 2.251459, 'adjClose': 2.251459, 'volume': 2911039833.0, 'unadjustedVolume': 2911039833.0, 'change': -0.00307, 'changePercent': -0.136, 'vwap': 2.25577, 'label': 'October 02, 21', 'changeOverTime': -0.00136}, {'date': '2021-10-01', 'open': 2.116249, 'high': 2.274002, 'low': 2.096256, 'close': 2.258127, 'adjClose': 2.258127, 'volume': 3235813427.0, 'unadjustedVolume': 3235813427.0, 'change': 0.14188, 'changePercent': 6.704, 'vwap': 2.20946, 'label': 'October 01, 21', 'changeOverTime': 0.06704}, {'date': '2021-09-30', 'open': 2.066589, 'high': 2.134077, 'low': 2.053454, 'close': 2.114452, 'adjClose': 2.114452, 'volume': 2621620164.0, 'unadjustedVolume': 2621620164.0, 'change': 0.04786, 'changePercent': 2.316, 'vwap': 2.10066, 'label': 'September 30, 21', 'changeOverTime': 0.02316}, {'date': '2021-09-29', 'open': 2.039015, 'high': 2.144665, 'low': 2.023027, 'close': 2.065688, 'adjClose': 2.065688, 'volume': 2869486117.0, 'unadjustedVolume': 2869486117.0, 'change': 0.02667, 'changePercent': 1.308, 'vwap': 2.07779, 'label': 'September 29, 21', 'changeOverTime': 0.01308}, {'date': '2021-09-28', 'open': 2.133217, 'high': 2.172157, 'low': 2.030042, 'close': 2.039139, 'adjClose': 2.039139, 'volume': 3092923646.0, 'unadjustedVolume': 3092923646.0, 'change': -0.09408, 'changePercent': -4.41, 'vwap': 2.08045, 'label': 'September 28, 21', 'changeOverTime': -0.0441}, {'date': '2021-09-27', 'open': 2.212038, 'high': 2.271561, 'low': 2.133972, 'close': 2.135905, 'adjClose': 2.135905, 'volume': 2990138100.0, 'unadjustedVolume': 2990138100.0, 'change': -0.07613, 'changePercent': -3.442, 'vwap': 2.1 ...
