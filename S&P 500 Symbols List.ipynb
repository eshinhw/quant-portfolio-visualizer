# %%
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = data[0]
df.head(10)
# Out:
#   Symbol                    Security SEC filings             GICS Sector  \
# 0    MMM                  3M Company     reports             Industrials
# 1    ABT         Abbott Laboratories     reports             Health Care
# 2   ABBV                 AbbVie Inc.     reports             Health Care
# 3   ABMD                 ABIOMED Inc     reports             Health Care
# 4    ACN               Accenture plc     reports  Information Technology
# 5   ATVI         Activision Blizzard     reports  Communication Services
# 6   ADBE                  Adobe Inc.     reports  Information Technology
# 7    AMD  Advanced Micro Devices Inc     reports  Information Technology
# 8    AAP          Advance Auto Parts     reports  Consumer Discretionary
# 9    AES                    AES Corp     reports               Utilities
#
#                               GICS Sub Industry     Headquarters Location  \
# 0                      Industrial Conglomerates       St. Paul, Minnesota
# ...

# %%
df = df[['Symbol', 'Security', 'GICS Sector', 'GICS Sub Industry', 'Date first added']]
df.head(10)
# Out:
#   Symbol                    Security             GICS Sector  \
# 0    MMM                  3M Company             Industrials
# 1    ABT         Abbott Laboratories             Health Care
# 2   ABBV                 AbbVie Inc.             Health Care
# 3   ABMD                 ABIOMED Inc             Health Care
# 4    ACN               Accenture plc  Information Technology
# 5   ATVI         Activision Blizzard  Communication Services
# 6   ADBE                  Adobe Inc.  Information Technology
# 7    AMD  Advanced Micro Devices Inc  Information Technology
# 8    AAP          Advance Auto Parts  Consumer Discretionary
# 9    AES                    AES Corp               Utilities
#
#                               GICS Sub Industry Date first added
# 0                      Industrial Conglomerates       1976-08-09
# 1                         Health Care Equipment       1964-03-31
# 2                               Pharmaceuticals       2012-12-31
# ...

# %%
symbols = df['Symbol'].values.tolist()
symbols
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
# ...

# %%
sectors = list(set(df['GICS Sector'].values.tolist()))
sectors
# Out:
# ['Financials',
#  'Industrials',
#  'Consumer Staples',
#  'Energy',
#  'Information Technology',
#  'Real Estate',
#  'Materials',
#  'Communication Services',
#  'Consumer Discretionary',
#  'Health Care',
#  'Utilities']

# %%
len(symbols)
# Out:
# 505

# %%
len(sectors)
# Out:
# 11

# %%
healthcare_df = df[df['GICS Sector'] == 'Health Care']
healthcare_df
# Out:
#     Symbol                      Security  GICS Sector  \
# 1      ABT           Abbott Laboratories  Health Care
# 2     ABBV                   AbbVie Inc.  Health Care
# 3     ABMD                   ABIOMED Inc  Health Care
# 11       A      Agilent Technologies Inc  Health Care
# 17    ALXN       Alexion Pharmaceuticals  Health Care
# ..     ...                           ...          ...
# 471   VRTX    Vertex Pharmaceuticals Inc  Health Care
# 483    WAT            Waters Corporation  Health Care
# 487    WST  West Pharmaceutical Services  Health Care
# 502    ZBH        Zimmer Biomet Holdings  Health Care
# 504    ZTS                        Zoetis  Health Care
#
#             GICS Sub Industry Date first added
# 1       Health Care Equipment       1964-03-31
# 2             Pharmaceuticals       2012-12-31
# 3       Health Care Equipment       2018-05-31
# 11      Health Care Equipment       2000-06-05
# 17              Biotechnology       2012-05-25
# ...
