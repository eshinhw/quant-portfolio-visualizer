# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://finviz.com/screener.ashx?v=111&f=cap_large,fa_div_o3,idx_sp500,ta_sma200_pa,ta_sma50_pa'
data = rq.get(url, headers={'User-Agent': 'Mozilla/5.0'})
data
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(data.content)
tbl = html.select('table.table-light')
tbl
df = pd.read_html(tbl[0].prettify())
df[0]
# Out:
#      0       1                                             2   \
# 0   No.  Ticker                                       Company
# 1     1     CAG                          Conagra Brands, Inc.
# 2     2     DRI                      Darden Restaurants, Inc.
# 3     3      ED                     Consolidated Edison, Inc.
# 4     4     EIX                          Edison International
# 5     5     EXC                            Exelon Corporation
# 6     6     HPQ                                       HP Inc.
# 7     7    INVH                         Invitation Homes Inc.
# 8     8     IRM                    Iron Mountain Incorporated
# 9     9     KHC                       The Kraft Heinz Company
# 10   10     KMB                    Kimberly-Clark Corporation
# 11   11     NEM                           Newmont Corporation
# 12   12      NI                                 NiSource Inc.
# 13   13     PEG  Public Service Enterprise Group Incorporated
# ...

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_html(url)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# ...

# %%
import yfinance as yf

# %%
k = yf.Ticker('K')
k
# Out:
# yfinance.Ticker object <K>

# %%
k.dividends
# Out:
# Date
# 1973-02-26 00:00:00-05:00    0.016875
# 1985-02-27 00:00:00-05:00    0.055000
# 1985-05-29 00:00:00-04:00    0.055000
# 1985-08-27 00:00:00-04:00    0.057500
# 1985-11-26 00:00:00-05:00    0.057500
#                                ...
# 2022-02-28 00:00:00-05:00    0.580000
# 2022-05-31 00:00:00-04:00    0.580000
# 2022-08-31 00:00:00-04:00    0.590000
# 2022-11-30 00:00:00-05:00    0.590000
# 2023-02-28 00:00:00-05:00    0.590000
# Name: Dividends, Length: 154, dtype: float64

# %%
k.history(interval='3mo', period='50y')
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1984-11-01 00:00:00-05:00   1.690238   1.886285   1.631954   1.870389
# 1985-02-01 00:00:00-05:00   1.865091   2.130018   1.817404   2.024047
# 1985-05-01 00:00:00-04:00   2.048169   2.566896   1.973301   2.294163
# 1985-08-01 00:00:00-04:00   2.350314   2.900159   2.285627   2.889377
# 1985-11-01 00:00:00-05:00   2.924287   3.228673   2.739480   3.196060
# ...                              ...        ...        ...        ...
# 2022-05-01 00:00:00-04:00  66.936818  73.078253  63.803237  71.492119
# 2022-08-01 00:00:00-04:00  72.169099  75.260666  67.507367  74.919327
# 2022-11-01 00:00:00-04:00  75.124988  75.547749  65.558618  67.426666
# 2023-02-01 00:00:00-05:00  67.792303  69.289109  63.182944  69.160240
# 2023-05-01 00:00:00-04:00  69.989998  72.300003  69.889999  71.529999
#
#                               Volume  Dividends  Stock Splits
# Date
# ...
