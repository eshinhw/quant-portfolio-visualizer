# %%
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get('https://quantshin.com').text
source
# Out:
# '<!DOCTYPE html><html\nclass="html" lang="en-US"><head><meta\ncharset="UTF-8"><link\nrel="profile" href="https://gmpg.org/xfn/11"> <script>function loadAsync(e,t){var a,n=!1;a=document.createElement("script"),a.type="text/javascript",a.src=e,a.onreadystatechange=function(){n||this.readyState&&"complete"!=this.readyState||(n=!0,"function"==typeof t&&t())},a.onload=a.onreadystatechange,document.getElementsByTagName("head")[0].appendChild(a)}</script> <meta\nname="viewport" content="width=device-width, initial-scale=1"><title>Home | Quant Shin</title><meta\nname="description" content="Hello and Welcome! My name is Eddie Shin, and\xa0I am a computer science major student at University of Toronto Scarborough (UTSC). I study and make posts" /><meta\nname="robots" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" /><link\nrel="canonical" href="https://quantshin.com/" /><meta\nproperty="og:locale" content="en_US" /><meta\nproperty="og:type" content="websi
# ...

# %%
soup = BeautifulSoup(source, 'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="html" lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <link href="https://gmpg.org/xfn/11" rel="profile"/>\n  <script>\n   function loadAsync(e,t){var a,n=!1;a=document.createElement("script"),a.type="text/javascript",a.src=e,a.onreadystatechange=function(){n||this.readyState&&"complete"!=this.readyState||(n=!0,"function"==typeof t&&t())},a.onload=a.onreadystatechange,document.getElementsByTagName("head")[0].appendChild(a)}\n  </script>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <title>\n   Home | Quant Shin\n  </title>\n  <meta content="Hello and Welcome! My name is Eddie Shin, and\xa0I am a computer science major student at University of Toronto Scarborough (UTSC). I study and make posts" name="description"/>\n  <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>\n  <link href="https://quantshin.com/" rel="canonical"/>\n  <meta content="en_US" property="og:l
# ...
